# %%
import os
import json
import pandas as pd
from googleapiclient import discovery
from dotenv import load_dotenv
from tqdm import tqdm
import time

# Load environment variables
load_dotenv()
API_KEY = os.getenv("API_KEY")

# Initialize Perspective API client
client = discovery.build(
    "commentanalyzer",
    "v1alpha1",
    developerKey=API_KEY,
    discoveryServiceUrl="https://commentanalyzer.googleapis.com/$discovery/rest?version=v1alpha1",
    static_discovery=False,
)

# Load the training dataset
file_path = './civility_data/test.tsv'
train_data = pd.read_csv(file_path, sep='\t')

# Function to get the toxicity score from Perspective API
def get_toxicity_score(text):
    analyze_request = {
        'comment': { 'text': text },
        'requestedAttributes': {'TOXICITY': {}},
        'languages': ['en']
    }
    try:
        response = client.comments().analyze(body=analyze_request).execute()
        score = response['attributeScores']['TOXICITY']['summaryScore']['value']
        return score
    except Exception as e:
        print(f"Error for text: {text[:30]}... -> {e}")
        return None

# Apply the function to each text in the dataset
# tqdm is used to show a progress bar as it can take some time to process all texts
toxicity_scores = []
for text in tqdm(train_data['text']):
    score = get_toxicity_score(text)
    toxicity_scores.append(score)
    time.sleep(1)  # Pause to avoid rate limiting; adjust based on API restrictions

# Add the scores to the dataset
train_data['toxicity_score'] = toxicity_scores

# Save the updated dataset to a new file
train_data.to_csv('./civility_data/test_with_perspectiveScore.tsv', sep='\t', index=False)
print("Updated dataset saved with toxicity scores.")
train_data
# Out:
# 100%|██████████| 6396/6396 [1:57:41<00:00,  1.10s/it]
# Updated dataset saved with toxicity scores.
#                                                    text  toxicity_score
# 0     Black Female Democrats Call for Changes in Par...        0.242826
# 1     After making fun of myself (and @USER a little...        0.162453
# 2                         You know what I hate? Negros.        0.853334
# 3     :(( I want him to rest 4ever :((( He is such a...        0.114090
# 4     I wish I can blink my eyes and I'll magically ...        0.288572
# ...                                                 ...             ...
# 6391                            Celtics lose to Bobcats        0.083999
# 6392  Does anyone know if things got easier out ther...        0.249241
# 6393  Nothing like girl time with junk food, warm su...        0.304398
# 6394  @USER This is a guy who weaponized the judicia...        0.743089
# 6395  @USER said drinks on him \ud83d\udc40\ud83d\ud...        0.231989
#
# [6396 rows x 2 columns]

# %%
import os
import json
import pandas as pd
from googleapiclient import discovery
from dotenv import load_dotenv
from concurrent.futures import ThreadPoolExecutor, as_completed
import time

# Load environment variables
load_dotenv()
API_KEY = os.getenv("API_KEY")

# Initialize Perspective API client
client = discovery.build(
    "commentanalyzer",
    "v1alpha1",
    developerKey=API_KEY,
    discoveryServiceUrl="https://commentanalyzer.googleapis.com/$discovery/rest?version=v1alpha1",
    static_discovery=False,
)

# Load the training dataset
file_path = './civility_data/train.tsv'
train_data = pd.read_csv(file_path, sep='\t')

# Function to get the toxicity score from Perspective API
def get_toxicity_score(text):
    analyze_request = {
        'comment': { 'text': text },
        'requestedAttributes': {'TOXICITY': {}}
    }
    try:
        response = client.comments().analyze(body=analyze_request).execute()
        score = response['attributeScores']['TOXICITY']['summaryScore']['value']
        return score
    except Exception as e:
        print(f"Error for text: {text[:30]}... -> {e}")
        return None

# Process texts concurrently
toxicity_scores = []
with ThreadPoolExecutor(max_workers=10) as executor:
    # Submit all texts to the executor for concurrent processing
    future_to_text = {executor.submit(get_toxicity_score, text): text for text in train_data['text']}
    for future in as_completed(future_to_text):
        try:
            toxicity_scores.append(future.result())
        except Exception as exc:
            print(f"Generated an exception: {exc}")
            toxicity_scores.append(None)

# Add the scores to the dataset
train_data['toxicity_score'] = toxicity_scores

# Save the updated dataset to a new file
train_data.to_csv('./civility_data/train_with_toxicity_scores.tsv', sep='\t', index=False)
print("Updated dataset saved with toxicity scores.")
# Out:
# Error for text: @USER @USER @USER @USER Fascis... -> [SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:2559)Error for text: @USER I second this they’re fu... -> [SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:2559)
#
# Error for text: @USER BREAKING: 9th Circuit Or... -> [SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:2559)Error for text: @USER Why cant ISIS blow up th... -> [SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:2559)
#
# Error for text: @USER @USER @USER @USER @USER ... -> [SSL: DECRYPTION_FAILED_OR_BAD_RECORD_MAC] decryption failed or bad record mac (_ssl.c:2559)Error for text: @USER @USER Free milk is a hea... -> [SSL: DECRYPTION_FAILED_OR_BAD_RECORD_MAC] decryption failed or bad record mac (_ssl.c:2559)
#
# Error for text: @USER Holder is worse than Joh... -> [SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:2559)
# Error for text: @USER &amp; this statement by ... -> [SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:2559)
# Error for text: @USER @USER You will be sadly ... -> [SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:2559)Error for text: @USER John kerry is a loser an... -> [SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:2559)
#
# Error for text: @USER @USER @USER @USER @USER ... -> [SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:2559)Error for text: @USER @USER @USER How dare you... -> [SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:2559)
#
# Error for text: @USER @USER You people calling... -> [SSL: DECRYPTION_FAILED_OR_BAD_RECORD_MAC] decryption failed or bad record mac (_ssl.c:2559)Error for text: @USER he is a psychic ain’t he... -> [SSL: DECRYPTION_FAILED_OR_BAD_RECORD_MAC] decryption failed or bad record mac (_ssl.c:2559)
#
# Error for text: #Maryland remember to vote #Re... -> [SSL: DECRYPTION_FAILED_OR_BAD_RECORD_MAC] decryption failed or bad record mac (_ssl.c:2559)
# Error for text: @USER If It could that shit wo... -> [SSL: DECRYPTION_FAILED_OR_BAD_RECORD_MAC] decryption failed or bad record mac (_ssl.c:2559)
# Error for text: @USER Almost forgot you was a ... -> [SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:2559)
# Error for text: @USER @USER Yes he is.... -> [SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:2559)
# Error for text: @USER @USER I’ll toast to me #... -> [SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:2559)
# Error for text: @USER Paris Terror Attacks bro... -> [SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:2559)
# Error for text: @USER can someone please expla... -> [SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:2559)
# Error for text: @USER @USER It used to mean th... -> [SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:2559)
# Error for text: @USER @USER @USER @USER I comp... -> [SSL: DECRYPTION_FAILED_OR_BAD_RECORD_MAC] decryption failed or bad record mac (_ssl.c:2559)
# Error for text: @USER @USER Her life is crappy... -> [SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:2559)
# Error for text: @USER @USER The petty semantic... -> [SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:2559)
# Error for text: @USER @USER Just block the idi... -> [SSL: DECRYPTION_FAILED_OR_BAD_RECORD_MAC] decryption failed or bad record mac (_ssl.c:2559)Error for text: @USER We met Ian Sinclair ther... -> [SSL: DECRYPTION_FAILED_OR_BAD_RECORD_MAC] decryption failed or bad record mac (_ssl.c:2559)
#
# Error for text: @USER @USER That so many “thou... -> [SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:2559)
# Error for text: #WednesdayWisdom Obama appoint... -> [SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:2559)
# Error for text: @USER @USER Oh I do dream big.... -> [SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:2559)Error for text: @USER @USER Nope. It's clear a... -> [SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:2559)
#
# Error for text: @USER God he is so easy to pla... -> [SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:2559)
# Error for text: @USER Congratulaions. . . who ... -> [SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:2559)
# Error for text: @USER Do you have any idea how... -> [SSL: DECRYPTION_FAILED_OR_BAD_RECORD_MAC] decryption failed or bad record mac (_ssl.c:2559)
# Error for text: @USER @USER The dems have done... -> [SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:2559)
# Error for text: @USER  Please call the vote.  ... -> [SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:2559)
# Error for text: @USER @USER @USER @USER @USER ... -> [SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:2559)
# Error for text: @USER @USER Lol. Why do I have... -> [SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:2559)
# Error for text: @USER @USER @USER @USER @USER ... -> [SSL] internal error (_ssl.c:2559)Error for text: @USER You are so sweet and ado... -> [SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:2559)
#
# Error for text: @USER So. Gut. &lt;3 &lt;3 &lt... -> [SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:2559)
# Error for text: @USER Doubt he is losing much ... -> [SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:2559)
# Error for text: @USER psychotic liberals fake ... -> [SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:2559)
# Error for text: @USER can you even imagine bei... -> [SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:2559)
# Error for text: @USER 😂yep truly she is a para... -> [SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:2559)Error for text: @USER Holder is guilty of mult... -> [SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:2559)
#
# Error for text: @USER what is this? We don’t w... -> [SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:2559)
# Error for text: @USER because he made guys dum... -> [SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:2559)
# Error for text: @USER Ouch. She is horrible.... -> [SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:2559)
# Error for text: @USER Can you answer one quest... -> [SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:2559)
# Error for text: #TuesdayThoughts  Seems like T... -> [SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:2559)Error for text: @USER Maybe it's because you a... -> [SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:2559)
#
# Error for text: @USER surely he is a saint of ... -> [SSL: DECRYPTION_FAILED_OR_BAD_RECORD_MAC] decryption failed or bad record mac (_ssl.c:2559)
# Error for text: #pugchat Just wanted to let yo... -> [SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:2559)
# Error for text: @USER @USER He lived in a coun... -> [SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:2559)
# Error for text: And yet I see daily Antifa dox... -> [SSL: DECRYPTION_FAILED_OR_BAD_RECORD_MAC] decryption failed or bad record mac (_ssl.c:2559)
# Error for text: @USER I got this... -> [SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:2559)
# Error for text: @USER @USER Both Labour &amp; ... -> [SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:2559)
# Error for text: @USER Treason he should hang h... -> [SSL: DECRYPTION_FAILED_OR_BAD_RECORD_MAC] decryption failed or bad record mac (_ssl.c:2559)
# Error for text: @USER @USER Be coo you got peo... -> [SSL: DECRYPTION_FAILED_OR_BAD_RECORD_MAC] decryption failed or bad record mac (_ssl.c:2559)
# Error for text: @USER Did MAGA hack your twitt... -> [PROV: CIPHER_OPERATION_FAILED] cipher operation failed (_ssl.c:2559)
# Error for text: @USER @USER So you think you a... -> [SSL: DECRYPTION_FAILED_OR_BAD_RECORD_MAC] decryption failed or bad record mac (_ssl.c:2559)
# Error for text: @USER Ok but please understand... -> [SSL: DECRYPTION_FAILED_OR_BAD_RECORD_MAC] decryption failed or bad record mac (_ssl.c:2559)
# Error for text: #loveforjess I might not know ... -> [SSL: DECRYPTION_FAILED_OR_BAD_RECORD_MAC] decryption failed or bad record mac (_ssl.c:2559)
# Error for text: @USER Trying to justify a deat... -> <HttpError 429 when requesting https://commentanalyzer.googleapis.com/v1alpha1/comments:analyze?key=AIzaSyBaLux5nlCL24zaSI_ra87mj9-s0h0SIos&alt=json returned "Quota exceeded for quota metric 'Analysis requests (AnalyzeComment)' and limit 'Analysis requests (AnalyzeComment) per minute' of service 'commentanalyzer.googleapis.com' for consumer 'project_number:740141255692'.". Details: "[{'@type': 'type.googleapis.com/google.rpc.ErrorInfo', 'reason': 'RATE_LIMIT_EXCEEDED', 'domain': 'googleapis.com', 'metadata': {'quota_limit_value': '60', 'quota_location': 'global', 'consumer': 'projects/740141255692', 'quota_metric': 'CommentAnalyzerService/analyze_requests', 'service': 'commentanalyzer.googleapis.com', 'quota_limit': 'AnalyzeRequestsPerMinutePerProject'}}, {'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Request a higher quota limit.', 'url': 'https://cloud.google.com/docs/quotas/help/request_increase'}]}]">
# Error for text: @USER Ya take advantage of the... -> [SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:2559)
# Error for text: @USER Aw boo you are the BEST ... -> [SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:2559)
# Error for text: @USER You have to admit. These... -> <HttpError 429 when requesting https://commentanalyzer.googleapis.com/v1alpha1/comments:analyze?key=AIzaSyBaLux5nlCL24zaSI_ra87mj9-s0h0SIos&alt=json returned "Quota exceeded for quota metric 'Analysis requests (AnalyzeComment)' and limit 'Analysis requests (AnalyzeComment) per minute' of service 'commentanalyzer.googleapis.com' for consumer 'project_number:740141255692'.". Details: "[{'@type': 'type.googleapis.com/google.rpc.ErrorInfo', 'reason': 'RATE_LIMIT_EXCEEDED', 'domain': 'googleapis.com', 'metadata': {'consumer': 'projects/740141255692', 'quota_metric': 'CommentAnalyzerService/analyze_requests', 'quota_location': 'global', 'service': 'commentanalyzer.googleapis.com', 'quota_limit': 'AnalyzeRequestsPerMinutePerProject', 'quota_limit_value': '60'}}, {'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Request a higher quota limit.', 'url': 'https://cloud.google.com/docs/quotas/help/request_increase'}]}]">
# Error for text: @USER We have the real facts..... -> [SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:2559)
# Error for text: @USER @USER You say you're par... -> [SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:2559)
# Error for text: @USER @USER And she is obvious... -> [SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:2559)
# Error for text: @USER More than that how low s... -> [SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:2559)
# Error for text: @USER If you cant give me stit... -> [SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:2559)Error for text: @USER Very simple....More gun ... -> [SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:2559)
#
# Error for text: @USER Im not apart of Antifa f... -> [SSL: DECRYPTION_FAILED_OR_BAD_RECORD_MAC] decryption failed or bad record mac (_ssl.c:2559)
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
